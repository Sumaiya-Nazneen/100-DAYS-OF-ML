# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("Advertising.csv")

# %%
print(df.corr())
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
print(df.corr()['Sales'])
# Out:
# Unnamed: 0   -0.051616
# TV            0.782224
# Radio         0.576223
# Newspaper     0.228299
# Sales         1.000000
# Name: Sales, dtype: float64

# %%
x = df.drop(columns=["Sales"])
y=df['Sales']

# %%
plt.scatter(df[['Newspaper']],df['Sales'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([20.56132515, 12.4727165 , 12.57531445, 17.67818293, 13.21660853,
#        12.78225366, 11.76135178, 12.03147576,  3.69737047, 12.40431294,
#         7.04085402, 17.06949173, 10.82262308,  8.73581514, 18.40966569,
#        20.84319293, 13.22318303, 23.16615648,  9.94865202, 14.0876895 ,
#        18.09143217, 14.57357926,  6.67177573, 16.40931699,  8.14887258,
#        15.40148663, 14.8975928 , 16.89166663, 19.2495722 ,  9.23523661,
#        21.51186915, 11.38636103,  7.64963909, 18.59154073,  7.49608931,
#        16.73113999, 23.17009864, 15.75964438, 10.01890106, 20.360289  ,
#        16.30492808, 17.28756679, 21.31124965, 13.85719015,  9.05355637,
#        15.12040886,  8.93033253, 21.57562276, 16.24022491,  8.25668736,
#        12.56613899,  9.25749239, 20.63007535, 20.02904312, 20.18829727,
#        21.36880272,  8.71370868, 12.71867724, 21.87281152, 17.97853472,
#         5.78189965, 22.8789639 , 16.66471755, 13.16771104, 16.99890965,
#         7.79734749,  9.02055551, 11.95476656, 18.80498245, 21.03748883,
#        17.76460316, 10.66578329, 10.45603335,  9.91477167, 17.19317123,
#        12.25374832,  4.55168744, 13.7821971 ,  8.88609041,  9.67293438,
#        11.49606714, 14.57108079, 10.26802337, 14.54943087, 20.74934811,
#        15.28378997, 11.62766947, 15.78957503, 11.96190147, 17.07728418,
#         9.92642482,  4.62906928, 19.22118096, 21.31473607, 10.45313453,
#        16.41227699, 12.48565075, 15.27930383, 24.08641726, 17.04838227,
#        13.88235031, 23.40382846, 17.47951532, 14.68567829, 20.13347356,
#        18.10236346,  6.26557229,  7.14601092,  3.71616089, 19.50599754,
#        14.79931485, 21.04924151, 13.7580452 , 16.28402693, 15.43954939,
#        13.12383506, 11.9908852 ,  6.59543105, 15.82880447,  6.94723344,
#        14.51575069,  8.08600739, 13.5043162 , 15.0770198 , 19.58864662,
#         9.199109  , 10.853053  ,  6.60333945, 22.12405753,  8.05769427,
#        10.54298529, 15.53058418,  8.52178704, 19.29914054, 12.14841688,
#        14.07464638, 11.54861053, 20.88594679,  9.8829191 , 19.57835768,
#         9.5361608 , 18.58961341, 19.25753083,  8.86024973, 10.22115089,
#         9.6614651 , 15.14604284, 23.28551697, 12.3647867 ,  9.94739924,
#        18.29943527, 10.15331207, 16.2941451 , 18.29399097, 15.42652473,
#         5.40294698, 15.59286164, 10.02706203, 10.65309994, 12.48651369,
#        14.24301218, 13.76850007, 14.93978774, 17.31050858, 11.05214979,
#        14.40155146, 10.99609819, 13.30559933, 17.2893908 , 17.75492019,
#         7.50385439, 14.47311247,  7.75007468, 11.93175137, 13.64787029,
#        24.78400641, 19.90569586, 12.21551975, 15.90275995, 12.37384963,
#        10.54324367, 13.90003067,  6.70666642, 24.24243249, 18.49753207,
#        20.78842232,  9.74353333, 17.06014092, 18.45947494,  6.22625262,
#        12.59171679,  8.4685193 ,  4.67207168, 18.44991909, 16.48198113,
#         5.48317272,  8.19778455, 12.72863505, 23.86690546, 15.06843283])

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8986489151417081

# %%
#ERROR y_Pred_train=model.predict(x_test)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.4650601050102927

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 1.7885761008659655

# %%
print(df.corr()['Sales'])
# Out:
# Unnamed: 0   -0.051616
# TV            0.782224
# Radio         0.576223
# Newspaper     0.228299
# Sales         1.000000
# Name: Sales, dtype: float64
